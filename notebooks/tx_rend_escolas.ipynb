# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# # Taxa de Rendimento Escolar
# ---

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
# importing plotly and cufflinks in offline mode
import cufflinks as cf
import plotly.offline
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)

import sys
import os
sys.path.append(os.path.dirname(os.getcwd()))

from config import RAW_PATH, TREAT_PATH
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Taxa de distorção idade série
df_tx_rend_2018 = pd.read_excel(RAW_PATH / 'TX_REND_ESCOLAS_2018.xlsx', skiprows=8)
df_tx_rend_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134459 entries, 0 to 134458
# Data columns (total 63 columns):
# Ano             134458 non-null object
# NO_REGIAO       134457 non-null object
# SG_UF           134457 non-null object
# CO_MUNICIPIO    134457 non-null float64
# NO_MUNICIPIO    134457 non-null object
# CO_ENTIDADE     134457 non-null float64
# NO_ENTIDADE     134457 non-null object
# TIPOLOCA        134457 non-null object
# Dependad        134457 non-null object
# tap_FUN         134457 non-null object
# tap_F14         134457 non-null object
# tap_F04         134457 non-null object
# tap_F58         134457 non-null object
# tap_F00         134457 non-null object
# tap_F01         134457 non-null object
# tap_F02         134457 non-null object
# tap_F03         134457 non-null object
# tap_F05         134457 non-null object
# tap_F06         134457 non-null object
# tap_F07         134457 non-null object
# tap_F08         134457 non-null object
# ...

# %%
df_tx_rend_2018.head()
# Out:
#     Ano NO_REGIAO SG_UF  CO_MUNICIPIO           NO_MUNICIPIO  CO_ENTIDADE  \
# 0  2018     Norte    RO     1100015.0  Alta Floresta D'Oeste   11022558.0
# 1  2018     Norte    RO     1100015.0  Alta Floresta D'Oeste   11024291.0
# 2  2018     Norte    RO     1100015.0  Alta Floresta D'Oeste   11024372.0
# 3  2018     Norte    RO     1100015.0  Alta Floresta D'Oeste   11024666.0
# 4  2018     Norte    RO     1100015.0  Alta Floresta D'Oeste   11024682.0
#
#                    NO_ENTIDADE TIPOLOCA   Dependad tap_FUN   ...   tab_F05  \
# 0        EIEEF HAP BITT TUPARI    Rural   Estadual    90.9   ...        --
# 1          EMMEF 7 DE SETEMBRO    Rural  Municipal    92.1   ...        --
# 2              EMEIEF ANA NERY   Urbana  Municipal    92.5   ...      14.3
# 3         EMEIEF BOA ESPERANCA    Rural  Municipal    94.4   ...         4
# 4  EEEF EURIDICE LOPES PEDROSO   Urbana   Estadual      85   ...         0
#
# ...

# %%
df_tx_rend_2018.columns
# Out:
# Index(['Ano', 'NO_REGIAO', 'SG_UF', 'CO_MUNICIPIO', 'NO_MUNICIPIO',
#        'CO_ENTIDADE', 'NO_ENTIDADE', 'TIPOLOCA', 'Dependad', 'tap_FUN',
#        'tap_F14', 'tap_F04', 'tap_F58', 'tap_F00', 'tap_F01', 'tap_F02',
#        'tap_F03', 'tap_F05', 'tap_F06', 'tap_F07', 'tap_F08', 'tap_MED',
#        'tap_M01', 'tap_M02', 'tap_M03', 'tap_M04', 'tap_MNS', 'tre_FUN',
#        'tre_F14', 'tre_F04', 'tre_F58', 'tre_F00', 'tre_F01', 'tre_F02',
#        'tre_F03', 'tre_F05', 'tre_F06', 'tre_F07', 'tre_F08', 'tre_MED',
#        'tre_M01', 'tre_M02', 'tre_M03', 'tre_M04', 'tre_MNS', 'tab_FUN',
#        'tab_F14', 'tab_F04', 'tab_F58', 'tab_F00', 'tab_F01', 'tab_F02',
#        'tab_F03', 'tab_F05', 'tab_F06', 'tab_F07', 'tab_F08', 'tab_MED',
#        'tab_M01', 'tab_M02', 'tab_M03', 'tab_M04', 'tab_MNS'],
#       dtype='object')

# %%
# filtro local
df_tx_rend_2018 = df_tx_rend_2018[(df_tx_rend_2018['SG_UF'] == 'RJ') 
                          & (df_tx_rend_2018['Dependad'] == 'Estadual')]

# filtro ensino médio
df_tx_rend_2018 = df_tx_rend_2018[['Ano', 'SG_UF', 'CO_MUNICIPIO', 'NO_MUNICIPIO',
                                   'CO_ENTIDADE', 'NO_ENTIDADE', 'TIPOLOCA', 'Dependad', 
                                   'tap_MED', 'tap_M01', 'tap_M02', 'tap_M03', 'tap_M04', # aprovacao
                                   'tre_MED', 'tre_M01', 'tre_M02', 'tre_M03', 'tre_M04', # reprovacao
                                   'tab_MED', 'tab_M01', 'tab_M02', 'tab_M03', 'tab_M04']] # abandono

df_tx_rend_2018 = df_tx_rend_2018[df_tx_rend_2018['tap_M01'] != '--']

# %%
df_tx_rend_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1096 entries, 87343 to 95654
# Data columns (total 23 columns):
# Ano             1096 non-null object
# SG_UF           1096 non-null object
# CO_MUNICIPIO    1096 non-null float64
# NO_MUNICIPIO    1096 non-null object
# CO_ENTIDADE     1096 non-null float64
# NO_ENTIDADE     1096 non-null object
# TIPOLOCA        1096 non-null object
# Dependad        1096 non-null object
# tap_MED         1096 non-null object
# tap_M01         1096 non-null object
# tap_M02         1096 non-null object
# tap_M03         1096 non-null object
# tap_M04         1096 non-null object
# tre_MED         1096 non-null object
# tre_M01         1096 non-null object
# tre_M02         1096 non-null object
# tre_M03         1096 non-null object
# tre_M04         1096 non-null object
# tab_MED         1096 non-null object
# tab_M01         1096 non-null object
# tab_M02         1096 non-null object
# tab_M03         1096 non-null object
# ...

# %%
# testando aqui! taxas do 1o ano EM 
import pandas_profiling
df_tx_rend_2018[['tap_M01', 'tre_M01', 'tab_M01']].profile_report()
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.3.0&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;Pandas Profiling Report&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...

# %%
df_tx_rend_2018.columns = df_tx_rend_2018.columns.str.upper() 
df_tx_rend_2018.to_csv(TREAT_PATH / 'df_tx_rend_em_rj_2018.csv')
